# %%
import vertexai
from vertexai.generative_models import GenerativeModel, Part
import os
from google.cloud import texttospeech
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../secret.json'
vertexai.init(project='pcloud2026', location="europe-west8")

# %%
model = GenerativeModel(model_name="gemini-2.5-flash")

response = model.generate_content(
    "Scrivi un breve paragrafo sull'uso di tecnologie cloud nell'ambito del pervasive computing"
)

print(response.text)
# Out:
# Le tecnologie cloud rivestono un ruolo cruciale nell'ambito del pervasive computing, fungendo da spina dorsale e abilitatore fondamentale. Dispositivi onnipresenti, spesso a basso consumo e con risorse computazionali limitate, si affidano al cloud per l'elaborazione di dati complessi e lo storage massivo generato da sensori e interazioni continue. Questo permette l'implementazione di funzionalità avanzate come l'intelligenza artificiale, l'apprendimento automatico e l'analisi contestuale in tempo reale, essenziali per rendere l'ambiente digitale veramente adattivo e predittivo. Inoltre, la scalabilità e la flessibilità del cloud sono indispensabili per gestire la moltitudine di sensori e attuatori distribuiti, garantendo una gestione efficiente e la disponibilità continua dei servizi che definiscono un'esperienza computazionale senza soluzione di continuità.

# %%
model = GenerativeModel(model_name="gemini-2.5-flash")

response = model.generate_content(
    [
        Part.from_uri(
            "gs://pcloud2026-1/test.jpg",
            mime_type="image/jpeg",
        ),
        "Cosa è rappresentato nell'immagine?",
    ]
)

print(response.text)
# Out:
# L'immagine mostra un **ritratto di un uomo**.
#
# Ecco una descrizione più dettagliata:
# *   **Soggetto principale:** Un uomo di mezza età, con capelli scuri e grigiastri sui lati e sulle tempie. Ha una carnagione chiara e guarda direttamente verso la fotocamera con un'espressione neutra e posata.
# *   **Abbigliamento:** Indossa un completo formale composto da una giacca scura (probabilmente blu navy o grigio scuro), una camicia bianca e una cravatta blu scuro, annodata con cura.
# *   **Sfondo:** Lo sfondo è sfocato, indicando una messa a fuoco sul soggetto. Si intravede della vegetazione, probabilmente foglie di alberi o arbusti, con tonalità che vanno dal rosso-marrone al verde scuro, suggerendo forse un ambiente esterno in autunno o una particolare specie di piante.
# *   **Illuminazione:** L'illuminazione sembra naturale e uniforme, senza ombre troppo marcate sul viso.
#
# In sintesi, si tratta di una foto professionale o semi-professionale di un uomo in abiti formali, probabilmente scattata all'aperto.

# %%
# Instantiates a client
client = texttospeech.TextToSpeechClient()

# Set the text input to be synthesized

txt = '''L'immagine mostra un uomo che si trova di fronte a una Tesla Cybertruck. 
L'uomo è vestito con una camicia bianca e dei jeans, e ha un sorriso sul volto. 
La Cybertruck è un veicolo elettrico prodotto da Tesla, Inc. 
È stato presentato per la prima volta nel 2019 e ha un design futuristico e accattivante'''

synthesis_input = texttospeech.SynthesisInput(text=txt)

# Build the voice request, select the language code ("en-US") and the ssml
# voice gender ("neutral")
voice = texttospeech.VoiceSelectionParams(
    language_code="it-IT", ssml_gender=texttospeech.SsmlVoiceGender.NEUTRAL
)

# Select the type of audio file you want returned
audio_config = texttospeech.AudioConfig(
    audio_encoding=texttospeech.AudioEncoding.MP3
)

# Perform the text-to-speech request on the text input with the selected
# voice parameters and audio file type
response = client.synthesize_speech(
    input=synthesis_input, voice=voice, audio_config=audio_config
)

# The response's audio_content is binary.
with open("output.mp3", "wb") as out:
    # Write the response to the output file.
    out.write(response.audio_content)
    print('Audio content written to file "output.mp3"')
# Out:
# Audio content written to file "output.mp3"
